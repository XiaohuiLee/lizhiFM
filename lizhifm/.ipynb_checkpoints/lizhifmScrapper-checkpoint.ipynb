# %% [markdown]
# # 荔枝爬虫
# 所有代码都已经托管在[Github](https://github.com/XiaohuiLee/lizhiFM)上，克隆仓库请用：
# ```
# git clone https://github.com/XiaohuiLee/lizhiFM.git
# ```
# ## 1、主要库
# * requests：http解析，网页内容抓取
# * pandas：数据规约整理
# * numpy：util工具类
# * re：正则表达式库，匹配模式
# * urllib：下载图片用
#
#
# base url:`http://www.lizhi.fm/hot/`
# ## 2、摘要
# 此爬虫的主要目的是爬取荔枝FM热榜下的dj信息，包括FM频道，DJ，个人信息主页，其中个人信息主页用于进一步抓取DJ信息的声音列表数量，播放量，粉丝数以及归属栏目，并将数据保存在本地平面文件。
# ## 3、主要步骤
# * 爬取：通过requests使用GET方法传输数据包，主页没有反爬虫机制，所以没有使用代理IP。
# * 解析：爬取回来的网页内容是UTF-8文本，使用正则表达式匹配字符串抽取信息。
# * 存储：将数据规约成DataFrame，调用to_csv方法写到csv文件中。

# %%
# 2018年1月28日20:44:43
import requests
import pandas as pd
import numpy as np
import urllib
import re
import os

# %%
# 一级页面
baseUrl = "http://www.lizhi.fm/hot/"
# 用户信息页面
prefix = 'http://www.lizhi.fm'

header = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"
}

sess = requests.Session()

df = pd.DataFrame(columns=['FM','Author','href'])
# 列名：
#     FM：FM频道ID
#     Author：DJ
#     href：DJ个人主页链接

# %%
# getContent(url)
# 作用：抓取网页内容
# 参数：
#         url：抓取地址
def getContent(url):
    contentRaw = sess.get(url, headers = header).text
    content = re.sub(r'\s+', "", contentRaw)
    return(content)

# %%
# fetchElements(content)
# 作用：抓取一级页面下的FM频道，DJ，以及个人主页链接
# 参数：
#     content：网页UTF-8文本内容
# 返回：
#     FM频道，DJ，以及个人主页
def fetchElements(content):
    #     fm列表正则表达式
    re_FM = r'<spanclass="radioBandbold">.*?<i>(.*?)</i></span>'
    #     作者列表正则表达式
    re_author = r'<pclass="radioNamefontYaHei"><ahref="//www.lizhi.fm/user/.*?">(.*?)</a>'
    #     作者个人网页列表正则表达式
    re_href = r'<liclass="radio_list"><ahref="(.*?)"class="radioCover"'
    #     作者头像列表正则表达式
    re_cover = r'data-echo="(.*?160x160.*?)"'
    
    #     匹配内容
    FM = re.findall(re_FM, content)
    author = re.findall(re_author, content)
    href = re.findall(re_href, content)
    cover = re.findall(re_cover, content)
    return(FM,author,href,cover)

# %%
# save2csv(df)
# 作用：将DataFrame格式数据保存到csv文件
# 参数：
#     df：待保存的DataFrame
# 返回：
#     无
def save2csv(df):
    with open('FM.CSV', 'a+', encoding='utf-8-sig') as csvfile:
        df.to_csv(csvfile, index=False, header=False,encoding='utf-8-sig')

# %%
# findNext(content)
# 作用：找到一级页面的下一页链接
# 参数：
#     content：网页纯文本
# 返回：
#     假如有下一页，找到短连接并返回，否则返回空
def findNext(content):
    Next = re.findall(r'</a><ahref="\./(\d+.html)"class="next">', content)
    return(Next)

# %%
# save_img(img_url,file_name=None,file_path='img')
# 作用：保存图片到本地
# 参数：
#     img_url：网页图片的远程连接
#     file_name：图片文件名
#     file_path：图片保存到本地的本地路径，默认是当前路径下的img文件夹
# 返回：
#     无
def save_img(img_url,file_name=None,file_path='img'):
    #保存图片到磁盘文件夹 file_path中，默认为当前脚本运行目录下的 /img文件夹
    try:
        if not os.path.exists(file_path):
            print('文件夹',file_path,'不存在，重新建立')
            #os.mkdir(file_path)
            os.makedirs(file_path)
        #获得图片后缀
        file_suffix = os.path.splitext(img_url)[1]
        #拼接图片名（包含路径）
        filename = '{}{}{}{}'.format(file_path,os.sep,file_name,file_suffix)
       #下载图片，并保存到文件夹中
        urllib.request.urlretrieve(img_url,filename=filename)
    except IOError as e:
        print('文件操作失败',e)
    except Exception as e:
        print('错误 ：',e)

# %%
# fetchUserInfo(content)
# 作用：抓取DJ个人信息，包括：声音列表数，播放数，粉丝数，归属一类标签，归属二类标签（若无标签返回空值）
# 参数：
#     content：二级页面纯文本内容
# 返回：
#     声音列表数，播放数，粉丝数，归属一类标签，归属二类标签
def fetchUserInfo(content):
#     声音列表数正则
    re_countRadioList = r'<iclass="stat-audio-icon"></i><spanclass="text">(.*?)</span>'
#     播放数正则
    re_countPlay = r'<iclass="stat-play-icon"></i><spanclass="text">(.*?)</span>'
#     粉丝数正则
    re_countFans = r'<iclass="stat-fans-icon"></i><spanclass="text">(.*?)</span>'
#     归属一类标签
    re_label1 = r'<spanclass="radio-info-label-b-label">(.*?)</span>'
#     归属二类标签
    re_label2 = r'class="radio-info-label-label">(.*?)</a>'
#     匹配模式
    countRadios = re.findall(re_countRadioList, content)[0]
    countPlays = re.findall(re_countPlay, content)[0]
    countFans = re.findall(re_countFans, content)[0]
    countPlays = chi2int(countPlays)
    countFans = chi2int(countFans)
    label1 = re.findall(re_label1, content)
    label2 = re.findall(re_label2, content)
#         判断label空不空
    if label1:
        label1 = label1[0]
    else:
        label1 = '空'
    if label2:
        label2 = label2[0]
    else:
        label2 = '空'
    return(countRadios, countPlays, countFans, label1, label2)

# %%
# grabUserInfo(href):
# 作用：抓取DJ个人信息的主函数，结合了getContent()和fetchUserInfo
# 参数：
#     href：二级页面地址
# 返回：
#     声音列表数，播放数，粉丝数，归属一类标签，归属二类标签
def grabUserInfo(href):
    url = prefix + href
    print("正在抓取："+url)
    userPage = getContent(url)
    Radios, Plays, Fans, label1, label2 = fetchUserInfo(userPage)
    print([Radios, Plays, Fans, label1, label2])
    return(Radios, Plays, Fans, label1, label2)

# %%
# makeDf(FM,Author)
# 作用：将FM频道ID和DJ存入到DataFrame
# 参数：
#     FM:待保存的Fm频道,数组形式
#     Author:待保存的DJ名字,数组形式
# 返回：
#     格式化后的df
def makeDf(FM,Author):
    df = pd.DataFrame(columns=['FM','Author'])
    df.FM = FM
    df.Author = Author
    return df

# %%
# chi2int(strin)
# 作用：因为抽取到的播放数,粉丝数都是用中国的"亿","万"作为单位,没法子被Python识别,因此有必要将这类单位转化成对应的十进制数
# 参数：
#     strin:待传入的字符串(播放数\粉丝数)
# 返回：
#     十进制数
def chi2int(strin):
    mask = r'\d+'
    result = re.findall(mask, strin)
    if "亿" in strin:
        print(result)
        yi = int(result[0]) * int(1e8)
        wan = int(result[1]) * int(1e4)
        strin = yi + wan
    elif "万" in strin:
        strin = int(float(strin[0:-1]) * int(1e4))
    return strin

# %%
# scrapper(baseUrl)
# 作用：全局main函数,集合了上述所有函数,是整个爬虫引擎的主体
# 参数：
#     baseurl:一级页面地址
# 返回：
#     找到当前一级页面地址的下一页地址
def scrapper(baseUrl):
    # 1、读取第一页，返回页面
#     columns=['Radios', "Plays", "Fans"]
    userDf = pd.DataFrame()
    content = getContent(baseUrl)
    # 2、获取FM和Author,Href, Cover
    FM, author, href, cover = fetchElements(content)
    for hr in href:
        Radios, Plays, Fans, label1, label2 = grabUserInfo(hr)
        se = pd.Series([Radios, Plays, Fans, label1, label2])
        userDf = userDf.append(se, ignore_index=True)
    # 3、1 保存到csv
    _Df = makeDf(FM, author)
    df = pd.concat([_Df, userDf], axis=1)
    save2csv(df)
    # 3、2保存头像到/img
    for co,au in zip(cover, author):
        save_img(co,file_name=au)
    # 4、找到下一页
    Next =findNext(content) 
    # 5、返回下一页
    return(Next)

# %%
# 爬虫爬取过程
Next = scrapper(baseUrl)
while Next:
    index = re.findall(r'\d+', str(Next[0]))
    print("这是第"+str(index[0])+"页了。")
    nextUrl = baseUrl + str(Next[0])
    print("爬取地址是："+nextUrl)
    Next = scrapper(nextUrl)
    if not Next:
        print("已经爬取完了哦！")
# Out:
# 正在抓取：http://www.lizhi.fm/user/1370548/
# ['4', '8557']
# ['828', 485570000, 1748000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/36376/
# ['3', '2848']
# ['441', 328480000, 2648000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/5147926/
# ['277', 51620000, 547000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/13821369/
# ['913', 52230000, 58000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/511685/
# ['459', 93690000, 1168000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/14302642/
# ['86', 10550000, 239000, '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/332/
# ['1884', 88330000, 716000, '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/12920027/
# ['4663', 31150000, 55000, '文化', '人文']
# 正在抓取：http://www.lizhi.fm/user/2552360964061657132/
# ['1784', 6459000, 40000, '文化', '惊悚']
# 正在抓取：http://www.lizhi.fm/user/2635684484736916012/
# ['20', 6282000, '3842', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2525632519289351212/
# ['412', 6622000, 19000, '娱乐', '偶像']
# 正在抓取：http://www.lizhi.fm/user/1302851/
# ['879', 77400000, 551000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2519197683107235884/
# ['570', 7085000, 11000, '亲子', '伴读']
# 正在抓取：http://www.lizhi.fm/user/95136/
# ['800', 19430000, 210000, '二次元', '游戏']
# 正在抓取：http://www.lizhi.fm/user/847232/
# ['1', '4063']
# ['287', 140630000, 1118000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/14637553/
# ['359', 3483000, 27000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2500203046358029356/
# ['967', 2986000, '7472', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/84190/
# ['1608', 82910000, 140000, '亲子', '伴读']
# 正在抓取：http://www.lizhi.fm/user/2637359781829789228/
# ['5', 2642000, 128000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2538138085155238444/
# ['64', 5686000, 217000, '情感', '私房话']
# 这是第2页了。
# 爬取地址是：http://www.lizhi.fm/hot/2.html
# 正在抓取：http://www.lizhi.fm/user/2544758401649219116/
# ['575', 2123000, 23000, '文化', '人文']
# 正在抓取：http://www.lizhi.fm/user/4578535/
# ['515', 4570000, 39000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2607459671058150956/
# ['239', 2797000, '5367', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/49930/
# ['241', 10200000, 140000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/14397828/
# ['767', 12580000, 74000, '文化', '人文']
# 正在抓取：http://www.lizhi.fm/user/198/
# ['508', 40440000, 425000, '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/6040648/
# ['215', 3897000, 19000, '脱口秀', '段子手']
# 正在抓取：http://www.lizhi.fm/user/2600041028077024812/
# ['312', 5308000, 150000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/340458/
# ['568', 30560000, 82000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2554978980702743084/
# ['103', 2783000, 13000, '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/2516509671381293612/
# ['466', 9305000, 27000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2589727127678364204/
# ['16', 15630000, 641000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2568674192368063532/
# ['193', 602000, '2094', '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/789085/
# ['2592', 10560000, 28000, '文化', '惊悚']
# 正在抓取：http://www.lizhi.fm/user/2549591670079014956/
# ['296', 3395000, 162000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/13235942/
# ['754', 4658000, 11000, '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/2588967152543157804/
# ['29', 2639000, 39000, '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/4860599/
# ['8', 185000, '6415', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2231180/
# ['975', 5430000, 12000, '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/4956981/
# ['468', 9440000, 267000, '情感', '治愈']
# 这是第3页了。
# 爬取地址是：http://www.lizhi.fm/hot/3.html
# 正在抓取：http://www.lizhi.fm/user/767949/
# ['4629', 55190000, 95000, '亲子', '伴读']
# 正在抓取：http://www.lizhi.fm/user/14287577/
# ['2370', 17480000, 59000, '语言', '粤语']
# 正在抓取：http://www.lizhi.fm/user/2635504860469501484/
# ['5', 20980000, 480000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2645315773186023468/
# ['5', 390000, '1147', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/27778383090120108/
# ['1720', 13900000, 82000, '资讯', '体育']
# 正在抓取：http://www.lizhi.fm/user/515588/
# ['136', 5517000, 108000, '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/2564468811556633644/
# ['3190', 5341000, 155000, '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/2566100841464052780/
# ['138', 770000, '2434', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2234472/
# ['471', 57910000, 870000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2593153184736135212/
# ['111', 1101000, '4713', '二次元', '游戏']
# 正在抓取：http://www.lizhi.fm/user/1114227/
# ['974', 10510000, 19000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/23250/
# ['276', 46190000, 643000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2646435705378541100/
# ['2', '35960', 12000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/11953/
# ['618', 54720000, 720000, '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/3024789/
# ['1169', 4364000, 21000, '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/2629895618816614956/
# ['60', 121000, '1528', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/14371600/
# ['567', 422000, '1144', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2588961901945234988/
# ['39', 1330000, 26000, '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2638414780283908140/
# ['2', 578000, '1654', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/6929/
# ['211', 1965000, 17000, '情感', '美文']
# 这是第4页了。
# 爬取地址是：http://www.lizhi.fm/hot/4.html
# 正在抓取：http://www.lizhi.fm/user/912703/
# ['315', 68430000, 613000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2512162629755121708/
# ['1505', 7887000, 65000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/759437/
# ['182', 7595000, 22000, '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/55587/
# ['493', 15870000, 80000, '文化', '惊悚']
# 正在抓取：http://www.lizhi.fm/user/2592115941322433580/
# ['10', 446000, 104000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/3102662/
# ['716', 18960000, 468000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/1929412/
# ['981', 9688000, 21000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/405513/
# ['1462', 40760000, 254000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2578966263290636844/
# ['253', 880000, 29000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2612607700805743660/
# ['235', 385000, '916', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/1313838/
# ['168', 25680000, 280000, '娱乐', '影视']
# 正在抓取：http://www.lizhi.fm/user/2607462269860322348/
# ['44', 2815000, 241000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2567679733481583148/
# ['20', 5684000, 318000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2566024738621283372/
# ['52', 792000, 15000, '二次元', '动漫']
# 正在抓取：http://www.lizhi.fm/user/2511214041131249196/
# ['18', 330000, '1433', '娱乐', '综艺']
# 正在抓取：http://www.lizhi.fm/user/2570156937394908204/
# ['172', 621000, '9909', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/3690128/
# ['223', 3513000, 224000, '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/3581460/
# ['357', 7396000, 28000, '语言', '粤语']
# 正在抓取：http://www.lizhi.fm/user/3449692/
# ['1246', 11270000, 40000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/276/
# ['635', 18470000, 135000, '脱口秀', '名嘴秀']
# 这是第5页了。
# 爬取地址是：http://www.lizhi.fm/hot/5.html
# 正在抓取：http://www.lizhi.fm/user/12345943/
# ['106', 4474000, 33000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2597698120976333868/
# ['17', 12520000, 523000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/408/
# ['297', 4113000, 24000, '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/2567221589559001132/
# ['555', 5527000, 331000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/103214/
# ['349', 6238000, 20000, '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/2500960530413266476/
# ['530', 820000, '2934', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2603711403755619884/
# ['8779', 721000, '2010', '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/3632443/
# ['590', 25290000, 357000, '音乐', '民谣']
# 正在抓取：http://www.lizhi.fm/user/5741178/
# ['190', 139000, 24000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2539416540048457260/
# ['306', 2314000, '5539', '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/2637467777155454508/
# ['9', '26508', 15000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2610272363543983660/
# ['4046', 1214000, '2254', '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/548218/
# ['608', 9994000, 76000, '语言', '英语交流']
# 正在抓取：http://www.lizhi.fm/user/13577498/
# ['86', 1319000, 12000, '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/2609564821708409388/
# ['1310', 748000, '2997', '广播剧', '现代剧']
# 正在抓取：http://www.lizhi.fm/user/2619941791536777772/
# ['3', 573000, '8478', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2644431632285379116/
# ['2', '6947', '5523', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2637895759910763052/
# ['14', 150000, 47000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/627/
# ['416', 27950000, 343000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2615479661388478508/
# ['2', '500', '6254', '空', '空']
# 这是第6页了。
# 爬取地址是：http://www.lizhi.fm/hot/6.html
# 正在抓取：http://www.lizhi.fm/user/2376944/
# ['86', 1056000, '5314', '文化', '惊悚']
# 正在抓取：http://www.lizhi.fm/user/405/
# ['487', 6550000, 41000, '脱口秀', '达人秀']
# 正在抓取：http://www.lizhi.fm/user/436/
# ['306', 24190000, 741000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2590941525339300908/
# ['219', 3336000, '9487', '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/28471945414645676/
# ['75', 3911000, 60000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/4913838/
# ['470', 7855000, 31000, '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/2623791471709806636/
# ['25', '57241', '863', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2577585536449418796/
# ['909', 1829000, 14000, '文化', '惊悚']
# 正在抓取：http://www.lizhi.fm/user/2640996182985046060/
# ['39', '6439', '5237', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2614868861207350828/
# ['11', '16055', '722', '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/2532010197828721708/
# ['101', 270000, 44000, '文化', '人文']
# 正在抓取：http://www.lizhi.fm/user/2591926554661174828/
# ['368', 558000, '1973', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/27659050913272236/
# ['222', 65660000, 1283000, '文化', '人文']
# 正在抓取：http://www.lizhi.fm/user/2558620745432425516/
# ['2', '8159', '99', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/13905815/
# ['105', 1789000, '9001', '脱口秀', '段子手']
# 正在抓取：http://www.lizhi.fm/user/60489/
# ['269', 34320000, 581000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/77363/
# ['345', 36710000, 599000, '语言', '英语交流']
# 正在抓取：http://www.lizhi.fm/user/2501205283631663660/
# ['80', 1061000, '7592', '广播剧', '现代剧']
# 正在抓取：http://www.lizhi.fm/user/61618/
# ['517', 9869000, 18000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2513590218902622252/
# ['4', 603000, 21000, '音乐', '翻唱']
# 这是第7页了。
# 爬取地址是：http://www.lizhi.fm/hot/7.html
# 正在抓取：http://www.lizhi.fm/user/5522278/
# ['2051', 745000, '2073', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2603288207823078444/
# ['63', 219000, 56000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2615264021819002924/
# ['44', '47163', '3627', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/5901469/
# ['83', 12320000, 19000, '娱乐', '影视']
# 正在抓取：http://www.lizhi.fm/user/2584818662958387756/
# ['19', 278000, '1680', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2579844869638971948/
# ['19', 184000, '7490', '情感', '私房话']
# 正在抓取：http://www.lizhi.fm/user/6246399/
# ['93', 694000, '4791', '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/2529799305218057260/
# ['17', 133000, '9705', '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2612379946984586284/
# ['27', 17760000, 40000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/4751060/
# ['141', 9008000, 370000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2579318643800449068/
# ['155', 16010000, 22000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2589493958198046764/
# ['12', 1852000, 234000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2497220322567297068/
# ['2477', 651000, '3764', '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2625529176769916972/
# ['17', 109000, '2420', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/763391/
# ['1461', 7984000, 40000, '情感', '心理']
# 正在抓取：http://www.lizhi.fm/user/406053/
# ['320', 83490000, 934000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/9064/
# ['268', 26490000, 151000, '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2552347058782970412/
# ['5', '1985', '1802', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/1679268/
# ['840', 7205000, 17000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/3595225/
# ['222', 19090000, 266000, '文化', '惊悚']
# 这是第8页了。
# 爬取地址是：http://www.lizhi.fm/hot/8.html
# 正在抓取：http://www.lizhi.fm/user/2593271802842646060/
# ['597', 2767000, 10000, '二次元', '同人']
# 正在抓取：http://www.lizhi.fm/user/2642900545613266476/
# ['1', 708000, 13000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/134098/
# ['373', 8291000, 67000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2589144740848898092/
# ['24', 4329000, 201000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2560395823201765420/
# ['34', 1288000, 265000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2625107575760968748/
# ['3', '36902', 22000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/297711/
# ['360', 3939000, 34000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2426946/
# ['222', 72980000, 755000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2502275520549642284/
# ['86', 1985000, 12000, '二次元', '同人']
# 正在抓取：http://www.lizhi.fm/user/2598911898143131692/
# ['6', '28750', 27000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2607681312892207148/
# ['17', '22607', '1671', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2603058188920808492/
# ['20', 7102000, 312000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2644111106117593644/
# ['12', '17979', 13000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/13661488/
# ['41', 1245000, 39000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/12637445/
# ['71', 7541000, 30000, '二次元', 'ACG音乐']
# 正在抓取：http://www.lizhi.fm/user/12318693/
# ['51', 479000, '4081', '广播剧', 'CV']
# 正在抓取：http://www.lizhi.fm/user/6937141/
# ['4', '5822', '7371', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/573388/
# ['120', 3511000, 78000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/6264400/
# ['38', 388000, 12000, '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2590188340593776172/
# ['297', 708000, '1328', '亲子', '伴读']
# 这是第9页了。
# 爬取地址是：http://www.lizhi.fm/hot/9.html
# 正在抓取：http://www.lizhi.fm/user/897566/
# ['242', 3359000, 17000, '文化', '历史']
# 正在抓取：http://www.lizhi.fm/user/2538333209815330348/
# ['45', 5695000, 395000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2553992738101188652/
# ['2167', 1561000, '5151', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/4254617/
# ['1', '8519', '1758', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/437472/
# ['547', 5989000, 57000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/12782249/
# ['179', 3992000, 169000, '广播剧', '古风剧']
# 正在抓取：http://www.lizhi.fm/user/2572445390549587500/
# ['49', 332000, '4428', '广播剧', '现代剧']
# 正在抓取：http://www.lizhi.fm/user/150431/
# ['240', 9529000, 73000, '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/2400242/
# ['132', 1638000, '5857', '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/13121998/
# ['620', 2111000, '6219', '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/5494315/
# ['386', 7812000, 106000, '广播剧', 'CV']
# 正在抓取：http://www.lizhi.fm/user/2501677493599721004/
# ['1095', 1810000, '6057', '广播剧', 'CV']
# 正在抓取：http://www.lizhi.fm/user/2643676276308359724/
# ['2', '8892', '6944', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2222/
# ['670', 5759000, '7605', '脱口秀', '段子手']
# 正在抓取：http://www.lizhi.fm/user/2636312059438000684/
# ['22', '75691', 34000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2649740126514182188/
# ['1', '794', '1538', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/1322660/
# ['2020', 16570000, 53000, '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/428214/
# ['587', 2954000, '7593', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2501202107503330860/
# ['594', 4531000, 11000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/12739604/
# ['792', 2877000, '8112', '亲子', '童话']
# 这是第10页了。
# 爬取地址是：http://www.lizhi.fm/hot/10.html
# 正在抓取：http://www.lizhi.fm/user/3074320/
# ['44', 322000, '6189', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2616993042506545708/
# ['1', '464', '1742', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2084170/
# ['1889', 6530000, 37000, '语言', '英语交流']
# 正在抓取：http://www.lizhi.fm/user/24555101931700908/
# ['1', '2182']
# ['225', 121820000, 2904000, '脱口秀', '段子手']
# 正在抓取：http://www.lizhi.fm/user/2628423814499579948/
# ['4', '19421', 10000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2529698523809814060/
# ['72', 1508000, 19000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2103384/
# ['152', 4158000, 139000, '生活', '女性']
# 正在抓取：http://www.lizhi.fm/user/2594515777841365548/
# ['10', 597000, 18000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2595686867246707244/
# ['116', 699000, 14000, '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/2827487/
# ['390', 10940000, 176000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2602876455669886508/
# ['36', 1148000, '8420', '情感', '私房话']
# 正在抓取：http://www.lizhi.fm/user/5832293/
# ['1367', 3073000, 39000, '语言', '英语交流']
# 正在抓取：http://www.lizhi.fm/user/2650037819285714476/
# ['5', '413', '1540', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/3535478/
# ['1414', 606000, '2219', '音乐', '纯音乐']
# 正在抓取：http://www.lizhi.fm/user/2601519692678816812/
# ['5', 1156000, 385000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/25684213132401068/
# ['250', 42010000, 1245000, '情感', '心理']
# 正在抓取：http://www.lizhi.fm/user/2521396953322769964/
# ['346', 2139000, 12000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/5331694/
# ['53', 368000, '3510', '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/972519/
# ['3098', 4247000, 17000, '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/278910/
# ['1572', 4492000, '8511', '语言', '其他']
# 这是第11页了。
# 爬取地址是：http://www.lizhi.fm/hot/11.html
# 正在抓取：http://www.lizhi.fm/user/886042/
# ['190', 22610000, 1090000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2540841511733470252/
# ['477', 1809000, '9107', '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/2604008956940721708/
# ['32', 183000, '1595', '广播剧', '现代剧']
# 正在抓取：http://www.lizhi.fm/user/2502416075502484524/
# ['52', 2619000, 80000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2578619992209088556/
# ['39', 498000, 13000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2505036570553053228/
# ['90', 2566000, 13000, '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2574645747301634604/
# ['61', 3188000, 274000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/3555724/
# ['104', 16060000, 520000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2585427850340139564/
# ['111', 957000, '6106', '资讯', '财经']
# 正在抓取：http://www.lizhi.fm/user/14146308/
# ['918', 1344000, '6504', '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/2598801077167346220/
# ['3', '840', '1287', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2626080143816889388/
# ['13', '37041', 19000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2606739712261462572/
# ['5', '39560', 23000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2626447055802721324/
# ['16', '8288', '6413', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/14606155/
# ['465', 13010000, 42000, '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/2645516730552945708/
# ['4', '7490', '7047', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2571326570807344684/
# ['172', 254000, '822', '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/2603527132478606892/
# ['240', 677000, '1010', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2558452140046077996/
# ['11', '2457', '1364', '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2520799422441130028/
# ['7', '30437', '9541', '音乐', '翻唱']
# 这是第12页了。
# 爬取地址是：http://www.lizhi.fm/hot/12.html
# 正在抓取：http://www.lizhi.fm/user/2070396/
# ['538', 10260000, 51000, '音乐', '纯音乐']
# 正在抓取：http://www.lizhi.fm/user/2638298288539060268/
# ['4', '4738', '981', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2625900072470780972/
# ['4', '1366', '2875', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2604480005331867692/
# ['21', '1882', '1153', '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/2140298/
# ['125', 79470000, 723000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2530628472276440108/
# ['63', 2208000, 38000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2650664223086179372/
# ['1', '153', '1365', '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/1291103/
# ['181', 2089000, 52000, '文化', '人文']
# 正在抓取：http://www.lizhi.fm/user/4031983/
# ['65', 4082000, 23000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2647493306714549804/
# ['3', '257', '1198', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2608077255583152684/
# ['25', 139000, '976', '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/4860553/
# ['44', '27563', '2030', '情感', '心理']
# 正在抓取：http://www.lizhi.fm/user/2621204275123398700/
# ['162', 799000, '1579', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/105534/
# ['307', 7592000, 52000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2587299895627493420/
# ['1', '74071', '7028', '娱乐', '偶像']
# 正在抓取：http://www.lizhi.fm/user/4838002/
# ['174', 9070000, 474000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2547221489910239276/
# ['55', 329000, 26000, '情感', '私房话']
# 正在抓取：http://www.lizhi.fm/user/2585026582303791148/
# ['10', 25080000, 24000, '娱乐', '偶像']
# 正在抓取：http://www.lizhi.fm/user/2579144731988086828/
# ['39', 853000, '3736', '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/14017685/
# ['107', 8877000, 30000, '亲子', '童话']
# 这是第13页了。
# 爬取地址是：http://www.lizhi.fm/hot/13.html
# 正在抓取：http://www.lizhi.fm/user/2605101431346689580/
# ['7', '1341', '1300', '音乐', '纯音乐']
# 正在抓取：http://www.lizhi.fm/user/451/
# ['129', 33830000, 1297000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/5474029/
# ['119', 28050000, 513000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/271/
# ['197', 14930000, 98000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2520280925609158188/
# ['56', 809000, '5052', '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/12359889/
# ['903', '19784', '74', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/14618364/
# ['10484', 9871000, 36000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2577632370921341996/
# ['45', 168000, '1712', '生活', '电台']
# 正在抓取：http://www.lizhi.fm/user/4280322/
# ['1659', 9783000, 23000, '语言', '英语交流']
# 正在抓取：http://www.lizhi.fm/user/2564782823056425516/
# ['431', 522000, '1534', '亲子', '伴读']
# 正在抓取：http://www.lizhi.fm/user/4920432/
# ['302', 1955000, 23000, '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/30654/
# ['767', 34520000, 756000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/4764920/
# ['89', 1345000, '4981', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2575956790361476140/
# ['30', 104000, '484', '音乐', '纯音乐']
# 正在抓取：http://www.lizhi.fm/user/128088/
# ['436', 59010000, 616000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/421002/
# ['176', 11390000, 455000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2614394808484125228/
# ['14', 191000, '3039', '情感', '私房话']
# 正在抓取：http://www.lizhi.fm/user/2577090721860155948/
# ['59', 246000, 17000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2593336296364893228/
# ['440', 547000, '2833', '脱口秀', '段子手']
# 正在抓取：http://www.lizhi.fm/user/742/
# ['212', 11560000, 77000, '脱口秀', '名嘴秀']
# 这是第14页了。
# 爬取地址是：http://www.lizhi.fm/hot/14.html
# 正在抓取：http://www.lizhi.fm/user/2617184632410917420/
# ['427', 2164000, '4224', '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/2513062071279755820/
# ['41', 7825000, 467000, '二次元', '同人']
# 正在抓取：http://www.lizhi.fm/user/12271865/
# ['552', 1965000, 17000, '文化', '历史']
# 正在抓取：http://www.lizhi.fm/user/2521380321272901676/
# ['205', 7856000, 198000, '文化', '诗歌']
# 正在抓取：http://www.lizhi.fm/user/2650305106087794220/
# ['5', '4107', '77', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2577207521347244588/
# ['44', 915000, 31000, '情感', '私房话']
# 正在抓取：http://www.lizhi.fm/user/12760959/
# ['347', 20210000, 687000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2513799061688018476/
# ['5', '1681', '1210', '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/3585419/
# ['23', '10045', '140', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2520052010082945580/
# ['180', 1365000, '9176', '广播剧', 'CV']
# 正在抓取：http://www.lizhi.fm/user/2649167199600319532/
# ['1', '326', '1053', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2650082401296084524/
# ['1', '119', '1110', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/3313934/
# ['324', 4104000, 38000, '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/91795/
# ['279', 15840000, 42000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/263/
# ['341', 9251000, 44000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/12595795/
# ['4658', 20040000, 88000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2645472077925943340/
# ['9', '3472', '3585', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/10278/
# ['141', 453000, '7518', '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/1684477/
# ['349', 12100000, 72000, '文化', '诗歌']
# 正在抓取：http://www.lizhi.fm/user/3785827/
# ['450', 1275000, '8473', '情感', '治愈']
# 这是第15页了。
# 爬取地址是：http://www.lizhi.fm/hot/15.html
# 正在抓取：http://www.lizhi.fm/user/2604453340025449516/
# ['34', '43384', '537', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2560749041311224876/
# ['72', '58920', '9355', '生活', '电台']
# 正在抓取：http://www.lizhi.fm/user/2626794645358173228/
# ['30', '20691', '9185', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/20790/
# ['217', 75230000, 541000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/362/
# ['279', 20080000, 603000, '生活', '旅行']
# 正在抓取：http://www.lizhi.fm/user/906295/
# ['203', 2572000, 12000, '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2561773068888780332/
# ['42', 569000, 35000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/56415/
# ['391', 20350000, 94000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/1708320/
# ['768', 3652000, 20000, '文化', '人文']
# 正在抓取：http://www.lizhi.fm/user/2580105945667083820/
# ['280', 193000, '1950', '语言', '英语交流']
# 正在抓取：http://www.lizhi.fm/user/2503095803468451372/
# ['192', 2429000, 22000, '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/1096860/
# ['566', 2645000, '7134', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2504000068242648108/
# ['1049', 4013000, 14000, '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/2529240802704037420/
# ['33', 1777000, 12000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2580211275536931884/
# ['95', 395000, '2446', '语言', '粤语']
# 正在抓取：http://www.lizhi.fm/user/2575996535991754284/
# ['147', 1690000, '6922', '音乐', '纯音乐']
# 正在抓取：http://www.lizhi.fm/user/2557328424132414508/
# ['328', 2678000, '7556', '生活', '公益']
# 正在抓取：http://www.lizhi.fm/user/2498731708674551340/
# ['319', 284000, '1278', '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/2613288096343448620/
# ['24', '85753', '107', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2562979439305416236/
# ['352', '39215', '252', '亲子', '育儿']
# 这是第16页了。
# 爬取地址是：http://www.lizhi.fm/hot/16.html
# 正在抓取：http://www.lizhi.fm/user/103347/
# ['276', 594000, '4663', '脱口秀', '达人秀']
# 正在抓取：http://www.lizhi.fm/user/574/
# ['1', '1876']
# ['144', 118760000, 100000000, '娱乐', '访谈']
# 正在抓取：http://www.lizhi.fm/user/575/
# ['1183', 33750000, 463000, '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/1340759/
# ['1100', 6695000, 73000, '资讯', '财经']
# 正在抓取：http://www.lizhi.fm/user/2563480913244696620/
# ['18', 119000, '5132', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/12052368/
# ['558', 11050000, 99000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2578381211354857004/
# ['239', 265000, '735', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2616251628075451948/
# ['513', 204000, '1529', '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/348/
# ['316', 14230000, 84000, '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/2584500483188617260/
# ['290', 651000, '3143', '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/2543133748661420588/
# ['335', 1109000, 11000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/6656700/
# ['75', 160000, '2459', '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2544536521169100844/
# ['13', 108000, '5889', '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2531822234814542892/
# ['120', 697000, '4138', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2198340/
# ['904', 3387000, 15000, '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/2526095467367431212/
# ['80', 200000, '1522', '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/2524555906064308780/
# ['543', 234000, '1317', '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/2584055069313422380/
# ['2', '357', '992', '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/2627863734214156844/
# ['3', '4777', '245', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/14182828/
# ['710', 5262000, 19000, '音乐', '流行']
# 这是第17页了。
# 爬取地址是：http://www.lizhi.fm/hot/17.html
# 正在抓取：http://www.lizhi.fm/user/2540119147307456044/
# ['201', 143000, '707', '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/2528024607764354092/
# ['330', 2100000, 166000, '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2537510764592001580/
# ['142', 2195000, '5251', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2608040771589700140/
# ['7', '21313', '3902', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2655333/
# ['496', 49200000, 103000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2534176768098099756/
# ['13', 364000, 20000, '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2522668338803499052/
# ['199', 3060000, 30000, '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/2606036507923081260/
# ['226', 526000, '1620', '亲子', '伴读']
# 正在抓取：http://www.lizhi.fm/user/2567154946378319404/
# ['85', 3698000, '7277', '亲子', '伴读']
# 正在抓取：http://www.lizhi.fm/user/2585220910265506860/
# ['19', '15572', '47', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2588385178009210412/
# ['4', 1188000, '4897', '音乐', '民谣']
# 正在抓取：http://www.lizhi.fm/user/2640143354322310188/
# ['59', 100000, 33000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/163159/
# ['320', 18630000, 650000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/14563482/
# ['807', 2800000, 46000, '语言', '英语交流']
# 正在抓取：http://www.lizhi.fm/user/3422312/
# ['67', 1893000, 216000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/362769/
# ['366', 1301000, '3950', '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/14170027/
# ['322', 3331000, 27000, '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/2651271441838032940/
# ['1', '59', '956', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2590794792121383468/
# ['10', 398000, '3197', '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2555559402265818668/
# ['492', 715000, '2382', '广播剧', '古风剧']
# 这是第18页了。
# 爬取地址是：http://www.lizhi.fm/hot/18.html
# 正在抓取：http://www.lizhi.fm/user/2639747493627939372/
# ['13', '15376', 15000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2624917710290095660/
# ['4', 283000, '4429', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2613847670452659756/
# ['24', '46888', 21000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2556875332999343148/
# ['364', 111000, '568', '亲子', '伴读']
# 正在抓取：http://www.lizhi.fm/user/2531235696901738028/
# ['99', 1320000, 12000, '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/7050661/
# ['1362', 1027000, '4626', '脱口秀', '达人秀']
# 正在抓取：http://www.lizhi.fm/user/2650139496443578412/
# ['1', '190', '905', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2611371082788600876/
# ['20', 142000, '6954', '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2605051929699052588/
# ['12', '68828', '4044', '情感', '私房话']
# 正在抓取：http://www.lizhi.fm/user/2542198910058604588/
# ['490', 604000, '1739', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2639152196128856108/
# ['64', '35153', '212', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/26477307565388460/
# ['3', 6184000, 538000, '娱乐', '偶像']
# 正在抓取：http://www.lizhi.fm/user/2583045112047554092/
# ['26', 211000, '6489', '音乐', '民谣']
# 正在抓取：http://www.lizhi.fm/user/2651059491324533804/
# ['1', '74', '884', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/13677495/
# ['947', 6920000, 34000, '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/12872079/
# ['54', 1510000, 65000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2531579672240684076/
# ['212', '89665', 14000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2505797702970378796/
# ['9', '4963', '3699', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2616940259507015724/
# ['19', 260000, '7087', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2611417945570600492/
# ['15', 171000, '1207', '情感', '治愈']
# 这是第19页了。
# 爬取地址是：http://www.lizhi.fm/hot/19.html
# 正在抓取：http://www.lizhi.fm/user/2555378231953050668/
# ['44', 457000, 129000, '娱乐', '影视']
# 正在抓取：http://www.lizhi.fm/user/14124059/
# ['16', 5626000, 87000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/430/
# ['1217', 5483000, 24000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2809285/
# ['119', 1070000, '5888', '广播剧', '现代剧']
# 正在抓取：http://www.lizhi.fm/user/13295469/
# ['16', '11390', '988', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/39313/
# ['243', 1380000, '6574', '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/2594660906932021804/
# ['821', 369000, '1422', '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/13502254/
# ['16', '27984', '225', '娱乐', '偶像']
# 正在抓取：http://www.lizhi.fm/user/1647840/
# ['31', 505000, '3858', '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/2577067428102954540/
# ['16', '93848', '1059', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2602657204032493612/
# ['3', '280', '852', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2624036677205884972/
# ['1', '170', '1258', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2632381723499658284/
# ['5', 841000, '6835', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2585422786615817772/
# ['91', 1738000, 231000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2640125994142880812/
# ['4', '5142', '198', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2505569653092933164/
# ['1693', 200000, '6462', '生活', '公益']
# 正在抓取：http://www.lizhi.fm/user/6564018/
# ['53', 8212000, 143000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2615830216618935340/
# ['8', '4183', '65', '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/5952506/
# ['310', 7196000, 445000, '情感', '心理']
# 正在抓取：http://www.lizhi.fm/user/2649797217614963244/
# ['3', '249', '818', '空', '空']
# 这是第20页了。
# 爬取地址是：http://www.lizhi.fm/hot/20.html
# 正在抓取：http://www.lizhi.fm/user/2570052524593219628/
# ['47', 114000, '6948', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2646820940723669548/
# ['1', '19493', '733', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/12872448/
# ['151', 6206000, 269000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2526356442253449260/
# ['29', 330000, '1171', '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/2520081739847361580/
# ['798', 212000, '868', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/5112172/
# ['105', 642000, '3544', '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/2601920123219499564/
# ['31', '5084', '38', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2619599211484865580/
# ['57', 178000, '1782', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2572237217780187692/
# ['94', 731000, 32000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2565033286224994860/
# ['48', '96141', '7097', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/6761252/
# ['44', 390000, '7575', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2522078182381360684/
# ['49', 981000, 201000, '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/505903/
# ['405', 23900000, 303000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2601552886336843820/
# ['9', '2229', '736', '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2564447240084700716/
# ['14', '1525', '1002', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2648334487045403180/
# ['7', '10142', '181', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/14313261/
# ['556', 3289000, '4965', '脱口秀', '名嘴秀']
# 正在抓取：http://www.lizhi.fm/user/2554914983542235180/
# ['294', 1605000, 11000, '广播剧', '古风剧']
# 正在抓取：http://www.lizhi.fm/user/2525835580831865388/
# ['3', '10450', '517', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2569305127348106796/
# ['93', 824000, 38000, '音乐', '翻唱']
# 这是第21页了。
# 爬取地址是：http://www.lizhi.fm/hot/21.html
# 正在抓取：http://www.lizhi.fm/user/2770501/
# ['172', 3586000, 27000, '广播剧', 'CV']
# 正在抓取：http://www.lizhi.fm/user/2620869826016632876/
# ['39', 129000, '5930', '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2646650505531531308/
# ['9', '7394', '130', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2622773427020364332/
# ['37', 314000, 52000, '情感', '心理']
# 正在抓取：http://www.lizhi.fm/user/2624234398802228780/
# ['17', '81042', '461', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/49509/
# ['238', 4786000, 37000, '语言', '影视英语']
# 正在抓取：http://www.lizhi.fm/user/5875301/
# ['92', 1027000, 11000, '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2623513870163694124/
# ['9', '81020', 11000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2538852647350037548/
# ['105', 210000, '905', '文化', '惊悚']
# 正在抓取：http://www.lizhi.fm/user/2628484691942868524/
# ['1', '26', '845', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/3790346/
# ['108', 207000, '3501', '生活', '电台']
# 正在抓取：http://www.lizhi.fm/user/2595637844489435692/
# ['24', 509000, 158000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2648125734205288492/
# ['3', '403', '1070', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/4771922/
# ['4', 912000, 151000, '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2515025397257001004/
# ['97', 621000, '4659', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2587672091052843564/
# ['6', '970', '773', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2513740070312074796/
# ['30', '7640', '3837', '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2649063752916449324/
# ['3', '353', '1149', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2590600736908504108/
# ['5', 594000, 39000, '二次元', 'ACG音乐']
# 正在抓取：http://www.lizhi.fm/user/2647511429329467436/
# ['33', '4487', '70', '空', '空']
# 这是第22页了。
# 爬取地址是：http://www.lizhi.fm/hot/22.html
# 正在抓取：http://www.lizhi.fm/user/2954539/
# ['142', 728000, '3572', '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/5574763/
# ['1240', 573000, '2923', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/28959116857531564/
# ['86', 1548000, 72000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/5991634/
# ['139', 924000, '5020', '娱乐', '影视']
# 正在抓取：http://www.lizhi.fm/user/2726046/
# ['298', 1140000, '7696', '广播剧', 'CV']
# 正在抓取：http://www.lizhi.fm/user/2518778/
# ['166', 9121000, 67000, '语言', '粤语']
# 正在抓取：http://www.lizhi.fm/user/2596525191255411756/
# ['10', 328000, '1465', '广播剧', '现代剧']
# 正在抓取：http://www.lizhi.fm/user/2613183019970799660/
# ['73', 129000, '442', '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/2504043129374160940/
# ['44', 475000, '3687', '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2600840905309420076/
# ['7', '8203', '76', '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2490148/
# ['191', 1811000, 14000, '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/2513816802261356588/
# ['105', 1283000, '8467', '脱口秀', '神吐槽']
# 正在抓取：http://www.lizhi.fm/user/2572435288694597164/
# ['20', 315000, '6830', '音乐', '民谣']
# 正在抓取：http://www.lizhi.fm/user/2538961698716877868/
# ['398', 319000, '847', '亲子', '伴读']
# 正在抓取：http://www.lizhi.fm/user/2497128161160634924/
# ['7', '2194', '793', '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/2581161156853372460/
# ['147', '33808', '3950', '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2548090737923962412/
# ['516', 1086000, '2343', '娱乐', '综艺']
# 正在抓取：http://www.lizhi.fm/user/6341331/
# ['4', '4984', '61', '情感', '心理']
# 正在抓取：http://www.lizhi.fm/user/2950484/
# ['333', 5732000, 33000, '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/2590743417870446636/
# ['13', 118000, '807', '情感', '治愈']
# 这是第23页了。
# 爬取地址是：http://www.lizhi.fm/hot/23.html
# 正在抓取：http://www.lizhi.fm/user/2567290890684492844/
# ['5', 1073000, 164000, '娱乐', '偶像']
# 正在抓取：http://www.lizhi.fm/user/2511394633768959532/
# ['218', 314000, '1045', '娱乐', '偶像']
# 正在抓取：http://www.lizhi.fm/user/2589985072674754604/
# ['46', 2625000, 48000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2505089662578866732/
# ['137', 649000, '677', '亲子', '育儿']
# 正在抓取：http://www.lizhi.fm/user/2636932510270598188/
# ['2', 466000, 11000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2649270570872725548/
# ['2', '676', '646', '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2645388203655823404/
# ['3', '19208', '2489', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2619128493803596844/
# ['106', 133000, '363', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2576173383416218156/
# ['5', '68196', '347', '文化', '人文']
# 正在抓取：http://www.lizhi.fm/user/2604815886808081452/
# ['6', '3062', '1320', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2522795328101777964/
# ['187', 2657000, '8462', '生活', '健康']
# 正在抓取：http://www.lizhi.fm/user/2510797629230899244/
# ['85', 290000, '1763', '娱乐', '影视']
# 正在抓取：http://www.lizhi.fm/user/578083/
# ['43', 242000, '3586', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2556530941045033516/
# ['25', 128000, 15000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2542532744979270188/
# ['14', 162000, 10000, '音乐', '翻唱']
# 正在抓取：http://www.lizhi.fm/user/2650151148440849452/
# ['2', '181', '635', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2615136626644760108/
# ['14', '96221', '9324', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2531767993672118828/
# ['14', '2063', '42', '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2627329218461972012/
# ['1', 301000, 12000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/6018/
# ['111', 5022000, 16000, '脱口秀', '神吐槽']
# 这是第24页了。
# 爬取地址是：http://www.lizhi.fm/hot/24.html
# 正在抓取：http://www.lizhi.fm/user/13457750/
# ['62', 1443000, '9354', '广播剧', '现代剧']
# 正在抓取：http://www.lizhi.fm/user/2262953/
# ['22', '98400', '1836', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/229/
# ['537', 8383000, 40000, '文化', '诗歌']
# 正在抓取：http://www.lizhi.fm/user/2521974345103342636/
# ['228', 1528000, '3607', '亲子', '伴读']
# 正在抓取：http://www.lizhi.fm/user/2616070318175304236/
# ['73', 286000, '1536', '音乐', '纯音乐']
# 正在抓取：http://www.lizhi.fm/user/27424405030704172/
# ['152', 45430000, 1089000, '文化', '人文']
# 正在抓取：http://www.lizhi.fm/user/6401398/
# ['271', 846000, '5188', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/1156633/
# ['137', 3487000, 29000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/6457983/
# ['30', '64728', '366', '广播剧', '纯爱']
# 正在抓取：http://www.lizhi.fm/user/2641473182300771372/
# ['2', '312', '642', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/265/
# ['405', 12760000, 56000, '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/4364660/
# ['114', 550000, '2892', '脱口秀', '达人秀']
# 正在抓取：http://www.lizhi.fm/user/2548341744081601068/
# ['542', 413000, '2498', '生活', '女性']
# 正在抓取：http://www.lizhi.fm/user/12521262/
# ['50', 956000, 21000, '生活', '电台']
# 正在抓取：http://www.lizhi.fm/user/2512864771220583468/
# ['1380', 270000, '2436', '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2502174030473858092/
# ['1016', 604000, 19000, '二次元', '古风']
# 正在抓取：http://www.lizhi.fm/user/2641595625377244204/
# ['13', '16549', '1256', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/14090296/
# ['9', '9520', '749', '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/369245/
# ['355', 8006000, 38000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2612657820629293612/
# ['3', '34064', '385', '情感', '恋爱']
# 这是第25页了。
# 爬取地址是：http://www.lizhi.fm/hot/25.html
# 正在抓取：http://www.lizhi.fm/user/5931300/
# ['39', '35392', '257', '音乐', '民谣']
# 正在抓取：http://www.lizhi.fm/user/2542954235892390444/
# ['3', 110000, '485', '广播剧', '现代剧']
# 正在抓取：http://www.lizhi.fm/user/2511916362773807660/
# ['155', 797000, '5347', '广播剧', '现代剧']
# 正在抓取：http://www.lizhi.fm/user/2590958046060091948/
# ['3', 142000, '1237', '广播剧', 'CV']
# 正在抓取：http://www.lizhi.fm/user/309/
# ['167', 1128000, '6317', '脱口秀', '达人秀']
# 正在抓取：http://www.lizhi.fm/user/2625436136463800364/
# ['139', '35317', '105', '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2552588871885929004/
# ['4', 457000, '1789', '亲子', '童话']
# 正在抓取：http://www.lizhi.fm/user/2603014813744609324/
# ['54', 132000, '1154', '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/2620338325961056812/
# ['10', '10621', '2228', '音乐', '流行']
# 正在抓取：http://www.lizhi.fm/user/4353126/
# ['151', 14450000, 142000, '情感', '美文']
# 正在抓取：http://www.lizhi.fm/user/2629237022088654892/
# ['153', '61460', 12000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2507897813130048556/
# ['182', 591000, '3845', '二次元', '宅文化']
# 正在抓取：http://www.lizhi.fm/user/2598385687360518700/
# ['339', 2711000, 230000, '文化', '有声书']
# 正在抓取：http://www.lizhi.fm/user/2579810232832128556/
# ['1', '30950', 27000, '娱乐', '偶像']
# 正在抓取：http://www.lizhi.fm/user/29917396002093612/
# ['88', 10450000, 188000, '空', '空']
# 正在抓取：http://www.lizhi.fm/user/2505296055085584428/
# ['56', 637000, '8359', '情感', '恋爱']
# 正在抓取：http://www.lizhi.fm/user/3273804/
# ['221', 1591000, 10000, '语言', '英语交流']
# 正在抓取：http://www.lizhi.fm/user/2574455995648348204/
# ['21', 461000, 147000, '情感', '治愈']
# 正在抓取：http://www.lizhi.fm/user/2536757450738034220/
# ['20', 1466000, 20000, '二次元', '同人']
# 正在抓取：http://www.lizhi.fm/user/2597636151040043052/
# ['10', 185000, '521', '情感', '心理']
# 文件操作失败 [Errno 22] Invalid argument: 'img\\昭北豆子|闲来吾室.jpg'
# 已经爬取完了哦！
